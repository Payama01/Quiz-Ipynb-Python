# %%
player_skills = {
  'Fireball': 5,
  'Ice Wall': 3,
  'Stealth': 2,
}

# %%
#no 1
player_skills['Stealth']
# Out:
# 2

# %%
player_skills['Fireball'] = 10

# %%
player_skills['Thunder'] = 1

# %%
for skill, level in player_skills.items():
  print(f"Skill {skill} is currently level {level}")
# Out:
# Skill Fireball is currently level 10
# Skill Ice Wall is currently level 3
# Skill Stealth is currently level 2
# Skill Thunder is currently level 1
