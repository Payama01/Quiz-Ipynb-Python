# %%
username = "admin"
password = "12345"

# %%
def login_sistem(username,password):
  if username == "admin" and password == "rahasia":
    return True 
  else:
    return False

# %%
login_sistem(username,password)
# Out:
# False
