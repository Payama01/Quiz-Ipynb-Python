# %%
#masukin umur
umur = 16

# %%
def cek_kategori_usia(umur):
  if umur < 12:
    print("Anak-anak")
  elif umur > 12 and umur < 17:
    print("Remaja")
  else:
    print("Dewasa")
  return

# %%
cek_kategori_usia(umur)
# Out:
# Remaja
