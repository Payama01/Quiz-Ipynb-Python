# %%
#masukan nilai ujian mu
nilai_ujian = 75

# %%
def cek_nilai_ujian(nilai):
  if nilai >= 70:
    print("Kamu Lulus!")
  else:
    print("Kamu Tidak Lulus!")

# %%
cek_nilai_ujian(nilai_ujian)
# Out:
# Kamu Lulus!
