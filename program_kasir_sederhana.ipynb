# %%
harga_barang = 1
total_harga = 0

# %%
while harga_barang > 0:
  harga_barang = int(input("Masukan harga: "))
  total_harga += harga_barang

print("Total belanjaan: " + str(total_harga))
# Out:
# Total belanjaan: 7000
