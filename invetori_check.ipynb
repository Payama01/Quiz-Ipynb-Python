# %%
inventory = ["Potion","Sword","Shield","Map"]

# %%
print(inventory[0])
print(inventory[3])
print(inventory[1:3])
print(inventory[10])
# Out:
# Potion
# Map
# ['Sword', 'Shield']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 print(inventory[3])
#       3 print(inventory[1:3])
# ----> 4 print(inventory[10])
#
# IndexError: list index out of range
