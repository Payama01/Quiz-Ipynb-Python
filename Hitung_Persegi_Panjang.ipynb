# %%
#Masukan Angka
panjang = 10
lebar = 5

# %%
def hitung_persegi_panjang(panjang,lebar):
  persegi_panjang = panjang * lebar
  print(persegi_panjang)

# %%
hitung_persegi_panjang(panjang, lebar)
# Out:
# 50
