# %%
inventory = ["Potion","Sword","Shield","Map"]

# %%
inventory.append("Key")
inventory.insert(1,"Helmet")

# %%
inventory.remove("Map")

# %%
inventory[2] = "Excalibur"

# %%
print(inventory)
# Out:
# ['Potion', 'Helmet', 'Excalibur', 'Shield', 'Key']
