# %%
kalimat = "Halo Python"
aiueo = "aiueoAIUEO"

# %%
def hitung_vokal(kalimat):
  aiueo = "aiueoAIUEO"
  jumlah = 0
  for huruf in kalimat:
    print(huruf)
    if huruf in aiueo:
      print(huruf)
      jumlah = jumlah + 1
  return jumlah

# %%
hitung_vokal(kalimat)
# Out:
# H
# a
# a
# l
# o
# o
#
# P
# y
# t
# h
# o
# o
# n
# 3
